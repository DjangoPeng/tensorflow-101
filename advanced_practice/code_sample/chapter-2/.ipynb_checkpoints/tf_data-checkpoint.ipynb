# %% [markdown]
# ## 使用 tf.data.Dataset 加载数据

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.2.0-rc4'

# %% [markdown]
# ### List 列表数据

# %%
dataset = tf.data.Dataset.from_tensor_slices([1, 2, 3])
for element in dataset:
    print(element)
# Out:
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)

# %% [markdown]
# ### Generator 生成器

# %%
import itertools

def gen():
    for i in itertools.count(1):
        yield (i, [1] * i)

# %%
dataset = tf.data.Dataset.from_generator(
    gen,
    (tf.int64, tf.int64),
    (tf.TensorShape([]), tf.TensorShape([None])))

# %%
list(dataset.take(3).as_numpy_iterator())
# Out:
# [(1, array([1])), (2, array([1, 1])), (3, array([1, 1, 1]))]

# %% [markdown]
# ### 文本文件

# %%
parent_dir = "/work/chapter-2/files"
FILE_NAMES = ['cowper.txt', 'derby.txt', 'butler.txt']

# %%
import os

def labeler(example, index):
    return example, tf.cast(index, tf.int64)  

labeled_data_sets = []

for i, file_name in enumerate(FILE_NAMES):
    lines_dataset = tf.data.TextLineDataset(os.path.join(parent_dir, file_name))
    labeled_dataset = lines_dataset.map(lambda ex: labeler(ex, i))
    labeled_data_sets.append(labeled_dataset)

# %%
BUFFER_SIZE = 50000
BATCH_SIZE = 64
TAKE_SIZE = 5000

all_labeled_data = labeled_data_sets[0]
for labeled_dataset in labeled_data_sets[1:]:
    all_labeled_data = all_labeled_data.concatenate(labeled_dataset)

all_labeled_data = all_labeled_data.shuffle(
    BUFFER_SIZE, reshuffle_each_iteration=False)

# %%
for ex in all_labeled_data.take(5):
    print(ex)
# Out:
# (<tf.Tensor: shape=(), dtype=string, numpy=b'Aetolian by descent, ruler over the Argives, brave Diomed the son of'>, <tf.Tensor: shape=(), dtype=int64, numpy=2>)
# (<tf.Tensor: shape=(), dtype=string, numpy=b'Star-spangled, richly wrought, defended well;'>, <tf.Tensor: shape=(), dtype=int64, numpy=1>)
# (<tf.Tensor: shape=(), dtype=string, numpy=b'Large compensation was from Elis due.'>, <tf.Tensor: shape=(), dtype=int64, numpy=1>)
# (<tf.Tensor: shape=(), dtype=string, numpy=b'him a mound by the wide waters of the Hellespont. Then will one say'>, <tf.Tensor: shape=(), dtype=int64, numpy=2>)
# (<tf.Tensor: shape=(), dtype=string, numpy=b'In perfect loveliness of face and form.'>, <tf.Tensor: shape=(), dtype=int64, numpy=0>)

# %% [markdown]
# ## 使用 tf.keras.Model 管理模型
